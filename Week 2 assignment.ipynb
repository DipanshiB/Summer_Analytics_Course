# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('Chicago_Crime_Detective.csv')

# %%
df.head()
# Out:
#    Unnamed: 0       ID            Date            LocationDescription  Arrest  \
# 0           0  8951354  12/31/12 23:15                         STREET   False
# 1           1  8951141  12/31/12 22:00                         STREET   False
# 2           2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)   False
# 3           3  8952223  12/31/12 22:00                         STREET   False
# 4           4  8951608  12/31/12 21:30                         STREET   False
#
#    Domestic  Beat District CommunityArea  Year
# 0     False   623        6            69  2012
# 1     False  1213       12            24  2012
# 2     False  1622       16            11  2012
# 3     False   724        7            67  2012
# 4     False   211        2            35  2012

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# ID                      int64
# Date                   object
# LocationDescription    object
# Arrest                   bool
# Domestic                 bool
# Beat                    int64
# District               object
# CommunityArea          object
# Year                    int64
# dtype: object

# %%
type(df['Date'].iloc[0])
# Out:
# str

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
type(df['Date'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.dtypes
# Out:
# Unnamed: 0                      int64
# ID                              int64
# Date                   datetime64[ns]
# LocationDescription            object
# Arrest                           bool
# Domestic                         bool
# Beat                            int64
# District                       object
# CommunityArea                  object
# Year                            int64
# dtype: object

# %%
df.describe()
# Out:
#           Unnamed: 0            ID           Beat           Year
# count  191641.000000  1.916410e+05  191641.000000  191641.000000
# mean    95820.000000  4.968629e+06    1258.810771    2006.134940
# std     55322.135806  2.342997e+06     702.530465       3.520285
# min         0.000000  1.310022e+06     111.000000    2001.000000
# 25%     47910.000000  2.832144e+06     722.000000    2003.000000
# 50%     95820.000000  4.762956e+06    1121.000000    2006.000000
# 75%    143730.000000  7.201878e+06    1733.000000    2009.000000
# max    191640.000000  9.181151e+06    2535.000000    2012.000000

# %%
sorted(df['Date'])
# Out:
# [Timestamp('2001-01-01 00:01:00'),
#  Timestamp('2001-01-01 00:01:00'),
#  Timestamp('2001-01-01 00:01:00'),
#  Timestamp('2001-01-01 00:01:00'),
#  Timestamp('2001-01-01 00:05:00'),
#  Timestamp('2001-01-01 00:05:00'),
#  Timestamp('2001-01-01 00:05:00'),
#  Timestamp('2001-01-01 00:30:00'),
#  Timestamp('2001-01-01 00:30:00'),
#  Timestamp('2001-01-01 01:17:00'),
#  Timestamp('2001-01-01 01:50:00'),
#  Timestamp('2001-01-01 02:00:00'),
#  Timestamp('2001-01-01 03:00:00'),
#  Timestamp('2001-01-01 03:00:00'),
#  Timestamp('2001-01-01 03:57:00'),
#  Timestamp('2001-01-01 04:00:00'),
#  Timestamp('2001-01-01 04:30:00'),
#  Timestamp('2001-01-01 05:00:00'),
#  Timestamp('2001-01-01 05:00:00'),
#  Timestamp('2001-01-01 08:00:00'),
#  Timestamp('2001-01-01 09:00:00'),
#  Timestamp('2001-01-01 10:00:00'),
#  Timestamp('2001-01-01 10:00:00'),
#  Timestamp('2001-01-01 10:00:00'),
#  Timestamp('2001-01-01 10:12:00'),
#  Timestamp('2001-01-01 11:00:00'),
#  Timestamp('2001-01-01 12:00:00'),
# ...

# %%
df['Date'].iloc[95820]
# Out:
# Timestamp('2006-05-21 12:30:00')

# %%
df['Month'] = df['Date'].apply(lambda date : date.month)

# %%
df.head()
# Out:
#    Unnamed: 0       ID                Date            LocationDescription  \
# 0           0  8951354 2012-12-31 23:15:00                         STREET
# 1           1  8951141 2012-12-31 22:00:00                         STREET
# 2           2  8952745 2012-12-31 22:00:00  RESIDENTIAL YARD (FRONT/BACK)
# 3           3  8952223 2012-12-31 22:00:00                         STREET
# 4           4  8951608 2012-12-31 21:30:00                         STREET
#
#    Arrest  Domestic  Beat District CommunityArea  Year  Month
# 0   False     False   623        6            69  2012     12
# 1   False     False  1213       12            24  2012     12
# 2   False     False  1622       16            11  2012     12
# 3   False     False   724        7            67  2012     12
# 4   False     False   211        2            35  2012     12

# %%
df['Month'].value_counts()
# Out:
# 10    17086
# 7     16801
# 8     16572
# 12    16426
# 11    16063
# 9     16060
# 1     16047
# 5     16035
# 6     16002
# 3     15758
# 4     15280
# 2     13511
# Name: Month, dtype: int64

# %%
df['Weekday'] = df['Date'].apply(lambda x : x.dayofweek)

# %%
df.head(5)
# Out:
#    Unnamed: 0       ID                Date            LocationDescription  \
# 0           0  8951354 2012-12-31 23:15:00                         STREET
# 1           1  8951141 2012-12-31 22:00:00                         STREET
# 2           2  8952745 2012-12-31 22:00:00  RESIDENTIAL YARD (FRONT/BACK)
# 3           3  8952223 2012-12-31 22:00:00                         STREET
# 4           4  8951608 2012-12-31 21:30:00                         STREET
# 5           5  8950793 2012-12-31 20:30:00                         STREET
# 6           6  8950760 2012-12-31 20:10:00                         STREET
# 7           7  8951611 2012-12-31 20:00:00                         STREET
# 8           8  8951802 2012-12-31 19:00:00                         STREET
# 9           9  8950706 2012-12-31 18:00:00                         STREET
#
#    Arrest  Domestic  Beat District CommunityArea  Year  Month  Weekday
# 0   False     False   623        6            69  2012     12        0
# ...

# %%
df['Weekday'].value_counts()
# Out:
# 4    29284
# 2    27416
# 0    27397
# 3    27319
# 5    27118
# 1    26791
# 6    26316
# Name: Weekday, dtype: int64

# %%
df[df['Arrest']== True]['Month'].value_counts()
# Out:
# 1     1435
# 12    1397
# 10    1342
# 8     1329
# 7     1324
# 3     1298
# 11    1256
# 4     1252
# 9     1248
# 2     1238
# 6     1230
# 5     1187
# Name: Month, dtype: int64

# %%
df['Year'] = df['Date'].apply(lambda x : x.year)

# %%
df.head()
# Out:
#    Unnamed: 0       ID                Date            LocationDescription  \
# 0           0  8951354 2012-12-31 23:15:00                         STREET
# 1           1  8951141 2012-12-31 22:00:00                         STREET
# 2           2  8952745 2012-12-31 22:00:00  RESIDENTIAL YARD (FRONT/BACK)
# 3           3  8952223 2012-12-31 22:00:00                         STREET
# 4           4  8951608 2012-12-31 21:30:00                         STREET
#
#    Arrest  Domestic  Beat District CommunityArea  Year  Month  Weekday
# 0   False     False   623        6            69  2012     12        0
# 1   False     False  1213       12            24  2012     12        0
# 2   False     False  1622       16            11  2012     12        0
# 3   False     False   724        7            67  2012     12        0
# 4   False     False   211        2            35  2012     12        0

# %%
sns.countplot(x='Year', data=df)

# %%
Arrest_Count = df[df['Arrest']== True]['Year'].value_counts()

# %%
Arrest_Count.iloc[6]
# Out:
# 1212

# %%
df['Year'].value_counts()
# Out:
# 2001    20669
# 2002    18753
# 2004    16862
# 2003    16657
# 2005    16484
# 2006    16098
# 2011    15637
# 2010    15497
# 2008    14445
# 2007    14280
# 2012    14092
# 2009    12167
# Name: Year, dtype: int64

# %%
1212 / 14280
# Out:
# 0.08487394957983194

# %%
df['LocationDescription'].value_counts()
# Out:
# STREET                                             156564
# PARKING LOT/GARAGE(NON.RESID.)                      14852
# OTHER                                                4573
# ALLEY                                                2308
# GAS STATION                                          2111
# DRIVEWAY - RESIDENTIAL                               1675
# RESIDENTIAL YARD (FRONT/BACK)                        1536
# RESIDENCE                                            1302
# RESIDENCE-GARAGE                                     1176
# VACANT LOT/LAND                                       985
# VEHICLE NON-COMMERCIAL                                817
# SIDEWALK                                              462
# CHA PARKING LOT/GROUNDS                               405
# AIRPORT/AIRCRAFT                                      363
# POLICE FACILITY/VEH PARKING LOT                       266
# PARK PROPERTY                                         255
# ...

# %%
Top5  = df[df['LocationDescription'] is in ['STREET','PARKING LOT/GARAGE(NON.RESID.)','ALLEY','GAS STATION','DRIVEWAY - RESIDENTIAL']]
# Out:
#   File "<ipython-input-61-a1d73f027583>", line 1
#     Top5  = df[df['LocationDescription'] is in ['STREET','PARKING LOT/GARAGE(NON.RESID.)','ALLEY','GAS STATION','DRIVEWAY - RESIDENTIAL']]
#                                              ^
# SyntaxError: invalid syntax

# %%
df[df['LocationDescription'] == 'GAS STATION']['Weekday'].value_counts()
# Out:
# 5    338
# 6    336
# 4    332
# 3    282
# 0    280
# 2    273
# 1    270
# Name: Weekday, dtype: int64
